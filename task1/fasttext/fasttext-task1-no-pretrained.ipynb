# %%
# we assume models are already created
# these are the global variables used when computing all the metrics

import fasttext

_dataDir = "../../data/"
ftlabel = "__label__"
temas = [1,2,3,4]

# best models in with no pretrained vectors in _model_<tema>_best_at_<k>.bin
# best models in with pretrained vectors in _model_<tema>_best_at_<k>.bin

# prefix for the models to load THIS IS THE ONLY LINE TO CHANGE TO CHARGE OTHER MODELS
model_name = "_model_"

# %% [markdown]
# ### First load all the models and the test data (dev+test)

# %%
# load best models at 1
models_at_1 = [None]*5
models_at_5 = [None]*5
for i in temas:
    models_at_1[i] = fasttext.load_model(model_name + str(i) + "_best_at_1.bin")
    models_at_5[i] = fasttext.load_model(model_name + str(i) + "_best_at_5.bin")

# %%
# utility function for reading list values for fasttext

import string

def read_text_file_for_ft_input(filename):
    with open(filename) as f:
        out = []
        for line in f:
            strdata = "".join([c for c in line[:-1] if c not in string.punctuation]).lower()
            ### This is because I found a string in the data that is empty after removing punctuation
            if strdata == '':
                strdata = ' '
            out.append(strdata)
    return out

def read_numbers_file_for_ft_input(filename):
    with open(filename) as f:
        out = []
        for line in f:
            out.append(int(line))
    return out

# %%
# load data to predict

#train_x = [None]*5
#train_y = [None]*5

test_x = [None]*5
test_y = [None]*5

dev_x = [None]*5
dev_y = [None]*5

for i in temas:

#    train_x[i] = read_text_file_for_ft_input(
#        _dataDir + "x_train_tema_" + str(i) + "_categorias_pnud_0.txt")
#    train_y[i] = read_numbers_file_for_ft_input(
#        _dataDir + "y_train_tema_" + str(i) + "_categorias_pnud_0.txt")
    
    dev_x[i] = read_text_file_for_ft_input(
        _dataDir + "x_dev_tema_" + str(i) + "_categorias_pnud_0.txt")
    dev_y[i] = read_numbers_file_for_ft_input(
        _dataDir + "y_dev_tema_" + str(i) + "_categorias_pnud_0.txt")
    
    test_x[i] = read_text_file_for_ft_input(
        _dataDir + "x_test_tema_" + str(i) + "_categorias_pnud_0.txt")
    test_y[i] = read_numbers_file_for_ft_input(
        _dataDir + "y_test_tema_" + str(i) + "_categorias_pnud_0.txt")

# %% [markdown]
# ### Compute the predictions

# %%
#### sizes = [None,5,5,5,5]

#predict_at_1_train = [None]*5
#predict_at_5_train = [None]*5

predict_at_1_dev = [None]*5
predict_at_5_dev = [None]*5

predict_at_1_test = [None]*5
predict_at_5_test = [None]*5


# size of the list of predicted 
sizes = [None,1,1,1,1]
for i in temas:
#    predict_at_1_train[i] = models_at_1[i].predict(train_x[i],k= sizes[i])
    predict_at_1_dev[i] = models_at_1[i].predict(dev_x[i],k= sizes[i])
    predict_at_1_test[i] = models_at_1[i].predict(test_x[i],k= sizes[i])

# size of the list of predicted 
sizes = [None,5,5,5,5]
for i in temas:    
#    predict_at_5_train[i] = models_at_5[i].predict(train_x[i],k= sizes[i])   
    predict_at_5_dev[i] = models_at_5[i].predict(dev_x[i],k= sizes[i])    
    predict_at_5_test[i] = models_at_5[i].predict(test_x[i],k= sizes[i])

# %%
# transform labels to int values
# this is needed because fasttext produces precitions as __label__<number_of_category>

def label_to_int(L):
    for i in temas:
        for j in range(len(L[i])):
            for k in range(len(L[i][j])):
                L[i][j][k] = int(L[i][j][k][9:])
                           
#label_to_int(predict_at_1_train)
#label_to_int(predict_at_5_train)
label_to_int(predict_at_1_dev)
label_to_int(predict_at_5_dev)
label_to_int(predict_at_1_test)
label_to_int(predict_at_5_test)


# utility function to select the first prediction from a list of predictions
def first_prediction(L):
    out = []
    for l in L:
        out.append(l[0])
    return out

# %% [markdown]
# <br/>
# <br/>
# <br/>
#
# # Metrics on dev + test set with best models accodring to recall@1

# %% [markdown]
# ### Metrics for predictions on dev set

# %%
from sklearn import metrics

for i in [1,2,3,4]:
    # load categories first
    categoriesFile = _dataDir + "categorias_tema_" + str(i) + "_pnud_0.txt"
    categories = []
    with open(categoriesFile) as f:
        for line in f:
            categories.append(line[:-1])

    predicted = first_prediction(predict_at_1_dev[i])
    print("Tema " + str(i))
    print(metrics.classification_report(dev_y[i],predicted,target_names=categories))
# Out:
# Tema 1
#                                                           precision    recall  f1-score   support
#
#                                           Amistad cívica       0.20      0.04      0.06        26
#                                     Autonomía / Libertad       0.66      0.62      0.64       168
#                                   Bien Común / Comunidad       0.60      0.66      0.63       275
#                                               Ciudadanía       0.00      0.00      0.00        17
#                                               Democracia       0.64      0.76      0.69       380
#                                               Desarrollo       0.35      0.37      0.36        52
#                                        Descentralización       0.87      0.90      0.88       307
#                                                 Dignidad       0.61      0.67      0.64       193
#                                               Diversidad       0.36      0.26      0.30        73
#                                     Emprendimiento libre       0.68      0.62      0.65        24
#                                        Equidad de género       0.80      0.72      0.76       166
#                                        Estado de Derecho       0.60      0.57      0.58       143
#                                             Estado laico       0.86      0.85      0.86       149
#                                       Identidad cultural       0.67      0.45      0.54        53
#                                                 Igualdad       0.62      0.73      0.67       369
#                                                Inclusión       0.51      0.50      0.51       123
#                                 Innovación / Creatividad       0.75      0.41      0.53        22
#                                              Integración       0.50      0.03      0.06        30
#                                                 Justicia       0.65      0.71      0.68       393
#                                        Multiculturalidad       0.56      0.59      0.58        86
#                                            Participación       0.58      0.57      0.57       120
#                                              Patriotismo       0.00      0.00      0.00         9
#                               Paz / Convivencia pacífica       0.49      0.37      0.42        49
#                                               Pluralismo       0.00      0.00      0.00        16
#                                        Plurinacionalismo       0.60      0.61      0.60        69
#                                                 Probidad       0.59      0.54      0.57       100
#                                                República       0.22      0.11      0.14        19
#                                                  Respeto       0.51      0.53      0.52       251
# Respeto / Conservación de la naturaleza o medio ambiente       0.82      0.88      0.85       373
#                                          Responsabilidad       0.68      0.53      0.60        49
#                                                Seguridad       0.72      0.68      0.70       127
#                                                Soberanía       0.67      0.64      0.65        55
#                                              Solidaridad       0.61      0.55      0.58       126
#                                            Subsidiaridad       0.68      0.44      0.54        34
#                                               Tolerancia       0.33      0.22      0.26        64
#                               Transparencia y publicidad       0.60      0.63      0.62        90
#                                                   Unidad       1.00      0.09      0.17        11
#
#                                              avg / total       0.64      0.65      0.64      4611
#
# Tema 2
#                                                    precision    recall  f1-score   support
#
#                                          A huelga       0.50      0.32      0.39        34
#                                    A la educación       0.82      0.88      0.85       510
#                             A la honra / Al honor       0.00      0.00      0.00         6
#                           A la identidad cultural       0.47      0.50      0.48        32
#                                  A la información       0.57      0.67      0.62        76
#                  A la integración de discapacidad       0.73      0.56      0.63        63
#                 A la integridad física y psíquica       0.48      0.33      0.39        61
#                                 A la nacionalidad       0.56      0.38      0.45        13
#                                A la participación       0.65      0.70      0.68       116
#                                        A la salud       0.80      0.85      0.83       534
#               A la seguridad / Vida sin violencia       0.74      0.71      0.73       119
#                             A la seguridad social       0.76      0.71      0.73       190
#                                         A la vida       0.75      0.84      0.79       245
#                               A la vivienda digna       0.85      0.85      0.85       228
#     A sindicalizarse y a la negociación colectiva       0.66      0.71      0.68        95
#                                A sufragio / Votar       0.67      0.67      0.67        93
#                      Acceso a información pública       0.44      0.30      0.36        27
#                               Acceso a la cultura       0.61      0.54      0.58        35
#                             Al salario equitativo       0.79      0.83      0.81       174
#                                        Al trabajo       0.66      0.66      0.66       107
#                          De los pueblos indígenas       0.83      0.84      0.83        92
#                  De petición ante las autoridades       0.00      0.00      0.00         6
#                                      De propiedad       0.75      0.72      0.74        58
#                             Derecho de asociación       0.62      0.36      0.46        22
#              Derechos del niño, niña y adolecente       0.74      0.72      0.73       103
#                                          Igualdad       0.47      0.44      0.45       121
#                              Igualdad ante la ley       0.62      0.74      0.67       265
#                 Igualdad ante las cargas públicas       0.00      0.00      0.00         3
#                        Igualdad ante los tributos       0.83      0.50      0.62        10
# Igualdad de acceso a la justicia / Debido proceso       0.39      0.27      0.32        55
#                                Igualdad de género       0.60      0.59      0.59        93
#                              Libertad ambulatoria       0.00      0.00      0.00         5
#                            Libertad de conciencia       0.66      0.49      0.56        51
#                             Libertad de enseñanza       0.86      0.57      0.68        44
#                             Libertad de expresión       0.66      0.74      0.70       193
#                               Libertad de trabajo       0.83      0.22      0.34        23
#                                 Libertad personal       0.52      0.40      0.45        62
#        Libre iniciativa económica / Libre empresa       0.43      0.50      0.47        20
#                                 No discriminación       0.49      0.44      0.46       108
#                            Privacidad e intimidad       0.82      0.72      0.77        25
#               Proteccion judicial de los derechos       0.63      0.69      0.65        54
#          Respeto a la naturaleza / Medio ambiente       0.90      0.92      0.91       179
#                                  Reunión pacífica       0.00      0.00      0.00         6
#                    Ser elegido en cargos públicos       0.83      0.33      0.48        15
#
#                                       avg / total       0.71      0.72      0.71      4371
#
# Tema 3
#                                                                          precision    recall  f1-score   support
#
#                                      Cumplimiento de las leyes y normas       0.69      0.65      0.67       368
#                                   Cumplimiento de obligaciones fiscales       0.71      0.58      0.64       160
#                 Cumplimiento de tratados y obligaciones internacionales       0.85      0.72      0.78       160
#         De protección y conservación de patrimonio histórico y cultural       0.91      0.86      0.89       443
#                                           De satisfacer cargas públicas       0.75      0.14      0.24        42
#                  Deberes de protección de conservación de la naturaleza       0.88      0.90      0.89       552
#                         Ejercicio legítimo y no abusivo de los derechos       0.71      0.73      0.72       347
# Protección, promoción y respeto de los derechos humanos y fundamentales       0.71      0.78      0.75       566
#                                            Respeto de derechos de otros       0.66      0.66      0.66       414
#                                             Respeto por la constitución       0.74      0.79      0.76       437
#                                                         Responsabilidad       0.67      0.70      0.69       236
#                                                 Servicio a la comunidad       0.78      0.80      0.79       288
#
#                                                             avg / total       0.76      0.76      0.76      4013
#
# Tema 4
#                                                                      precision    recall  f1-score   support
#
#                                     Cambio o reforma constitucional       0.80      0.80      0.80       246
#                                               Congreso o parlamento       0.71      0.77      0.74       349
#                         Contraloría general / Tribunales de cuentas       0.75      0.81      0.78       198
#                                     Defensor del Pueblo / Ciudadano       0.70      0.77      0.74       333
#                                                División territorial       0.53      0.30      0.38        63
#                                                 Estado de excepción       0.84      0.64      0.73        42
#                                                     Forma de Estado       0.66      0.59      0.62       201
#                                                     Fuerzas Armadas       0.82      0.83      0.83       271
#                                          Gobierno local / Municipal       0.71      0.70      0.71       235
#                          Gobierno nacional (estructura y funciones)       0.37      0.20      0.26        76
#                                                 Gobierno provincial       0.61      0.39      0.48        51
#                                                   Gobierno regional       0.59      0.68      0.63       263
#                                                Jefatura de gobierno       0.00      0.00      0.00        21
#                           Juicio político /acusación constitucional       0.64      0.71      0.68       129
#                                             Justicia constitucional       0.67      0.54      0.60       101
#                                                  Justicia electoral       0.77      0.56      0.65        64
#                             Ministerio Público / Defensoría Pública       0.44      0.19      0.27        88
#                                 Plebiscitos, referendos y consultas       0.78      0.87      0.83       496
#                             Poder judicial (estructura y funciones)       0.62      0.69      0.65       272
#                                         Presidencia de la República       0.58      0.58      0.58       196
# Régimen de gobierno presidencial /Semi-presidencial / Parlamentario       0.73      0.71      0.72       235
#
#                                                         avg / total       0.69      0.70      0.69      3930
# /Users/jperez/anaconda3/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### Metrics for predictions on test set

# %%
from sklearn import metrics

for i in [1,2,3,4]:
    # load categories first
    categoriesFile = _dataDir + "categorias_tema_" + str(i) + "_pnud_0.txt"
    categories = []
    with open(categoriesFile) as f:
        for line in f:
            categories.append(line[:-1])

    predicted = first_prediction(predict_at_1_test[i])
    print("Tema " + str(i))
    print(metrics.classification_report(test_y[i],predicted,target_names=categories))
# Out:
# Tema 1
#                                                           precision    recall  f1-score   support
#
#                                           Amistad cívica       0.22      0.07      0.11        27
#                                     Autonomía / Libertad       0.68      0.64      0.66       168
#                                   Bien Común / Comunidad       0.65      0.73      0.69       276
#                                               Ciudadanía       0.00      0.00      0.00        16
#                                               Democracia       0.60      0.73      0.66       380
#                                               Desarrollo       0.55      0.40      0.47        52
#                                        Descentralización       0.87      0.92      0.89       307
#                                                 Dignidad       0.60      0.63      0.62       193
#                                               Diversidad       0.42      0.24      0.30        72
#                                     Emprendimiento libre       0.53      0.33      0.41        24
#                                        Equidad de género       0.72      0.70      0.71       166
#                                        Estado de Derecho       0.52      0.54      0.53       144
#                                             Estado laico       0.87      0.88      0.87       149
#                                       Identidad cultural       0.53      0.43      0.48        53
#                                                 Igualdad       0.64      0.69      0.66       369
#                                                Inclusión       0.51      0.54      0.53       123
#                                 Innovación / Creatividad       0.73      0.38      0.50        21
#                                              Integración       0.17      0.03      0.06        29
#                                                 Justicia       0.69      0.71      0.70       393
#                                        Multiculturalidad       0.52      0.51      0.51        86
#                                            Participación       0.54      0.51      0.52       120
#                                              Patriotismo       1.00      0.11      0.20         9
#                               Paz / Convivencia pacífica       0.61      0.41      0.49        49
#                                               Pluralismo       0.50      0.06      0.11        17
#                                        Plurinacionalismo       0.63      0.67      0.65        69
#                                                 Probidad       0.68      0.61      0.64       100
#                                                República       0.33      0.11      0.16        19
#                                                  Respeto       0.49      0.56      0.52       250
# Respeto / Conservación de la naturaleza o medio ambiente       0.81      0.86      0.83       374
#                                          Responsabilidad       0.72      0.72      0.72        50
#                                                Seguridad       0.75      0.76      0.75       127
#                                                Soberanía       0.73      0.65      0.69        55
#                                              Solidaridad       0.64      0.59      0.61       126
#                                            Subsidiaridad       0.67      0.55      0.60        33
#                                               Tolerancia       0.49      0.31      0.38        64
#                               Transparencia y publicidad       0.62      0.68      0.65        90
#                                                   Unidad       1.00      0.09      0.17        11
#
#                                              avg / total       0.65      0.66      0.65      4611
#
# Tema 2
#                                                    precision    recall  f1-score   support
#
#                                          A huelga       0.56      0.40      0.47        35
#                                    A la educación       0.77      0.85      0.81       509
#                             A la honra / Al honor       0.00      0.00      0.00         6
#                           A la identidad cultural       0.62      0.39      0.48        33
#                                  A la información       0.60      0.71      0.65        75
#                  A la integración de discapacidad       0.68      0.61      0.64        62
#                 A la integridad física y psíquica       0.35      0.28      0.31        61
#                                 A la nacionalidad       0.25      0.21      0.23        14
#                                A la participación       0.65      0.67      0.66       116
#                                        A la salud       0.76      0.81      0.78       534
#               A la seguridad / Vida sin violencia       0.62      0.63      0.63       119
#                             A la seguridad social       0.63      0.65      0.64       189
#                                         A la vida       0.68      0.74      0.71       245
#                               A la vivienda digna       0.84      0.80      0.82       227
#     A sindicalizarse y a la negociación colectiva       0.72      0.70      0.71        94
#                                A sufragio / Votar       0.67      0.67      0.67        92
#                      Acceso a información pública       0.53      0.30      0.38        27
#                               Acceso a la cultura       0.70      0.58      0.64        36
#                             Al salario equitativo       0.76      0.78      0.77       174
#                                        Al trabajo       0.59      0.56      0.58       107
#                          De los pueblos indígenas       0.75      0.78      0.77        92
#                  De petición ante las autoridades       1.00      0.14      0.25         7
#                                      De propiedad       0.73      0.68      0.70        59
#                             Derecho de asociación       0.88      0.32      0.47        22
#              Derechos del niño, niña y adolecente       0.66      0.65      0.66       103
#                                          Igualdad       0.46      0.47      0.46       120
#                              Igualdad ante la ley       0.66      0.75      0.70       264
#                 Igualdad ante las cargas públicas       0.00      0.00      0.00         3
#                        Igualdad ante los tributos       1.00      0.64      0.78        11
# Igualdad de acceso a la justicia / Debido proceso       0.41      0.25      0.31        55
anaconda3/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# <br/>
# <br/>
# <br/>
#
# # Metrics on dev + test set with best models accodring to recall@5

# %% [markdown]
# ### Computing recall@5 defined as the total number of labels correctly predicted among the first 5 best ranked classes for every test case.
#
# For example, for a test case in which the true class is 7 and the top 5 predicted classes are 4,3,7,8,10, we count 1. In contrast, if for a test case in which the true class is 7 and the top 5 predicted classes are 1,2,3,4,5, we do not count.

# %%
# utility function to compute top k accuracy

def top_k_accuracy(gold,predicted,k):
    '''
    #Arguments
        gold: the true labels of the test cases (size N = number of test cases)
        predicted: ranked list of label predictions for every test case (size N x L, where L is assumed to be >= k)
        k: the number of elements in the predicted lists that should be considered to compute the metric
    #Returns
        The portion of cases (between 0 and 1) in which the true label value was among the first k predicted labels
    '''
    count = 0
    for g,pred_labels in zip(gold,predicted):
        if g in pred_labels[:k]:
                count += 1
    return count/len(gold)

# %%
for i in temas:   
    print("Tema " + str(i))
    print("---------")
    print("dev: \t" + str(round(100*top_k_accuracy(dev_y[i],predict_at_5_dev[i],5),1)) + "%")
    print("test: \t" + str(round(100*top_k_accuracy(test_y[i],predict_at_5_test[i],5),1)) + "%")     
    print()
# Out:
# Tema 1
# ---------
# dev: 	89.5%
# test: 	89.4%
#
# Tema 2
# ---------
# dev: 	91.7%
# test: 	90.5%
#
# Tema 3
# ---------
# dev: 	95.8%
# test: 	95.7%
#
# Tema 4
# ---------
# dev: 	91.6%
# test: 	91.0%

# %% [markdown]
# ### Computing average ranking size for correct predictions and size of ranking for different percentiles

# %%
import numpy as np

def ranking_sizes(gold,predicted):
    r_sizes = []
    for g,pred_labels in zip(gold,predicted):
        if g not in pred_labels:
            raise Exception('Label ' + str(g) + ' is not in the ranking. Unable to compute an average')
        r_sizes.append(pred_labels.index(g) + 1)
    return np.array(r_sizes)

# %%
# first compute the complete ranking
predict_total_test = [None]*5

# size of the list of predicted 
sizes = [None,37,44,12,21]
for i in temas:    
    predict_total_test[i] = models_at_5[i].predict(test_x[i],k= sizes[i])    

label_to_int(predict_total_test)

# %%
print("\t\tavgPos\t80%\t90%\t95%")

for i in temas:
    r_sizes = ranking_sizes(test_y[i],predict_total_test[i])

    
    m = round(np.mean(r_sizes),2)
    p1 = int(np.percentile(r_sizes,80))
    p2 = int(np.percentile(r_sizes,90))
    p3 = int(np.percentile(r_sizes,95))
    print("Tema " + str(i) + ":\t\t" + str(m) + "\t" + str(p1) + "\t" + str(p2) + "\t" + str(p3))
# Out:
# 		avgPos	80%	90%	95%
# Tema 1:		2.87	3	6	11
# Tema 2:		2.84	2	5	12
# Tema 3:		1.65	2	3	5
# Tema 4:		2.3	2	5	9

# %% [markdown]
# <br/>
# <br/>
# <br/>
#
# # More experiments

# %% [markdown]
# ### Predictions on test set with best model according to recall@1 considering 'concepto_original' + 'fundamento'

# %%
### what if we concatenate the 'concepto original'???

sizes = [None,1,1,1,1]

for i in temas:
    categoriesFile = _dataDir + "categorias_tema_" + str(i) + "_pnud_0.txt"
    categories = []
    with open(categoriesFile) as f:
        for line in f:
            categories.append(line[:-1])

    # create a new list for testing test_x_plus_category 
    test_x_plus_category = []
    test_x_category = []
    for f,cat in zip(test_x[i],test_y[i]):
        str_category = "".join([c for c in categories[cat] if c not in string.punctuation]).lower()
        test_x_plus_category.append(str_category + " " + f)
            
    predicted = first_prediction(models_at_1[i].predict(test_x_plus_category,k= sizes[i]))
    predicted_ints = []
    for l in predicted:
        predicted_ints.append(int(l[9:]))

                    
    print("Tema " + str(i))
    print(metrics.classification_report(test_y[i],predicted_ints,target_names=categories))
# Out:
# Tema 1
#                                                           precision    recall  f1-score   support
#
#                                           Amistad cívica       1.00      0.52      0.68        27
#                                     Autonomía / Libertad       0.90      0.98      0.94       168
#                                   Bien Común / Comunidad       0.87      0.98      0.92       276
#                                               Ciudadanía       0.00      0.00      0.00        16
#                                               Democracia       0.77      0.89      0.82       380
#                                               Desarrollo       0.91      0.56      0.69        52
#                                        Descentralización       0.97      0.98      0.98       307
#                                                 Dignidad       0.89      0.88      0.89       193
#                                               Diversidad       0.59      0.47      0.52        72
#                                     Emprendimiento libre       0.83      0.79      0.81        24
#                                        Equidad de género       0.87      0.88      0.87       166
#                                        Estado de Derecho       0.78      0.77      0.78       144
#                                             Estado laico       0.96      0.99      0.97       149
#                                       Identidad cultural       0.82      0.75      0.78        53
#                                                 Igualdad       0.83      0.85      0.84       369
#                                                Inclusión       0.75      0.79      0.77       123
#                                 Innovación / Creatividad       0.89      0.81      0.85        21
#                                              Integración       0.71      0.17      0.28        29
#                                                 Justicia       0.90      0.94      0.92       393
#                                        Multiculturalidad       0.65      0.64      0.65        86
#                                            Participación       0.71      0.62      0.66       120
#                                              Patriotismo       1.00      0.22      0.36         9
#                               Paz / Convivencia pacífica       0.87      0.82      0.84        49
#                                               Pluralismo       1.00      0.06      0.11        17
#                                        Plurinacionalismo       0.62      0.70      0.66        69
#                                                 Probidad       0.92      0.84      0.88       100
#                                                República       0.38      0.16      0.22        19
#                                                  Respeto       0.76      0.80      0.78       250
# Respeto / Conservación de la naturaleza o medio ambiente       0.94      0.97      0.95       374
#                                          Responsabilidad       0.94      0.98      0.96        50
#                                                Seguridad       0.95      0.97      0.96       127
#                                                Soberanía       0.91      0.87      0.89        55
#                                              Solidaridad       0.90      0.90      0.90       126
#                                            Subsidiaridad       0.88      0.70      0.78        33
#                                               Tolerancia       0.81      0.67      0.74        64
#                               Transparencia y publicidad       0.86      0.92      0.89        90
#                                                   Unidad       1.00      0.09      0.17        11
#
#                                              avg / total       0.85      0.85      0.85      4611
# /Users/jperez/anaconda3/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#
#                                             Respeto por la constitución       0.99      0.97      0.98       437
#                                                         Responsabilidad       0.98      0.87      0.92       236
#                                                 Servicio a la comunidad       0.98      1.00      0.99       288
#
#                                                             avg / total       0.97      0.97      0.97      4013
#
# Tema 4
#                                                                      precision    recall  f1-score   support
#
#                                     Cambio o reforma constitucional       0.97      0.98      0.98       246
#                                               Congreso o parlamento       0.97      0.97      0.97       349
#                         Contraloría general / Tribunales de cuentas       0.97      1.00      0.99       199
#                                     Defensor del Pueblo / Ciudadano       0.97      1.00      0.99       333
#                                                División territorial       0.93      0.89      0.91        63
#                                                 Estado de excepción       1.00      0.83      0.91        42
#                                                     Forma de Estado       0.89      0.92      0.90       202
#                                                     Fuerzas Armadas       0.99      1.00      0.99       271
#                                          Gobierno local / Municipal       0.97      0.99      0.98       235
#                          Gobierno nacional (estructura y funciones)       0.96      0.87      0.91        75
#                                                 Gobierno provincial       0.93      0.84      0.89        51
#                                                   Gobierno regional       0.94      0.89      0.92       262
#                                                Jefatura de gobierno       1.00      0.52      0.69        21
#                           Juicio político /acusación constitucional       0.96      0.98      0.97       129
#                                             Justicia constitucional       0.90      0.71      0.79       102
#                                                  Justicia electoral       0.98      0.94      0.96        64
#                             Ministerio Público / Defensoría Pública       0.99      0.90      0.94        87
#                                 Plebiscitos, referendos y consultas       0.99      0.99      0.99       495
#                             Poder judicial (estructura y funciones)       0.92      1.00      0.95       273
#                                         Presidencia de la República       0.95      0.91      0.93       195
# Régimen de gobierno presidencial /Semi-presidencial / Parlamentario       0.90      1.00      0.95       236
#
#                                                         avg / total       0.96      0.96      0.95      3930

# %% [markdown]
# ### Predictions on test considering only 'concepto_original'

# %%
### what if we only use the name of the class???

for i in [1,2,3,4]:
    categoriesFile = _dataDir + "categorias_tema_" + str(i) + "_pnud_0.txt"
    categories = []
    gold = []
    k = 0
    with open(categoriesFile) as f:
        for line in f:
            str_category = "".join([c for c in line[:-1] if c not in string.punctuation]).lower()
            categories.append(str_category)
            gold.append(k)
            k+=1
#    print(categories)
#    print(gold)
     
    predicted = models_at_1[i].predict(categories,k= 1)
    predicted = first_prediction(models_at_1[i].predict(categories,k= 1))
    predicted_ints = []
    for l in predicted:
        predicted_ints.append(int(l[9:]))
#    print(predicted_ints)
                    
    print("Tema " + str(i))
    print(metrics.classification_report(gold,predicted_ints,target_names=categories))
# Out:
# Tema 1
#                                                          precision    recall  f1-score   support
#
#                                          amistad cívica       0.50      1.00      0.67         1
#                                     autonomía  libertad       1.00      1.00      1.00         1
#                                   bien común  comunidad       1.00      1.00      1.00         1
#                                              ciudadanía       0.00      0.00      0.00         1
#                                              democracia       0.33      1.00      0.50         1
#                                              desarrollo       1.00      1.00      1.00         1
#                                       descentralización       1.00      1.00      1.00         1
#                                                dignidad       1.00      1.00      1.00         1
#                                              diversidad       1.00      1.00      1.00         1
#                                    emprendimiento libre       1.00      1.00      1.00         1
#                                       equidad de género       1.00      1.00      1.00         1
#                             libertad ambulatoria       0.00      0.00      0.00         1
#                           libertad de conciencia       1.00      1.00      1.00         1
#                            libertad de enseñanza       1.00      1.00      1.00         1
#                            libertad de expresión       1.00      1.00      1.00         1
#                              libertad de trabajo       1.00      1.00      1.00         1
#                                libertad personal       0.50      1.00      0.67         1
#        libre iniciativa económica  libre empresa       1.00      1.00      1.00         1
#                                no discriminación       1.00      1.00      1.00         1
#                           privacidad e intimidad       1.00      1.00      1.00         1
#              proteccion judicial de los derechos       1.00      1.00      1.00         1
#          respeto a la naturaleza  medio ambiente       1.00      1.00      1.00         1
#                                 reunión pacífica       0.00      0.00      0.00         1
#                   ser elegido en cargos públicos       1.00      1.00      1.00         1
#
#                                      avg / total       0.84      0.89      0.85        44
#
# Tema 3
#                                                                         precision    recall  f1-score   support
#
#                                     cumplimiento de las leyes y normas       1.00      1.00      1.00         1
#                                  cumplimiento de obligaciones fiscales       1.00      1.00      1.00         1
#                cumplimiento de tratados y obligaciones internacionales       1.00      1.00      1.00         1
#        de protección y conservación de patrimonio histórico y cultural       1.00      1.00      1.00         1
#                                          de satisfacer cargas públicas       1.00      1.00      1.00         1
#                 deberes de protección de conservación de la naturaleza       1.00      1.00      1.00         1
#                        ejercicio legítimo y no abusivo de los derechos       1.00      1.00      1.00         1
# protección promoción y respeto de los derechos humanos y fundamentales       1.00      1.00      1.00         1
#                                           respeto de derechos de otros       1.00      1.00      1.00         1
#                                            respeto por la constitución       1.00      1.00      1.00         1
#                                                        responsabilidad       1.00      1.00      1.00         1
#                                                servicio a la comunidad       1.00      1.00      1.00         1
#
#                                                            avg / total       1.00      1.00      1.00        12
#
# Tema 4
#                                                                   precision    recall  f1-score   support
#
#                                  cambio o reforma constitucional       1.00      1.00      1.00         1
#                                            congreso o parlamento       1.00      1.00      1.00         1
#                       contraloría general  tribunales de cuentas       1.00      1.00      1.00         1
#                                   defensor del pueblo  ciudadano       1.00      1.00      1.00         1
#                                             división territorial       1.00      1.00      1.00         1
#                                              estado de excepción       1.00      1.00      1.00         1
#                                                  forma de estado       1.00      1.00      1.00         1
#                                                  fuerzas armadas       1.00      1.00      1.00         1
#                                        gobierno local  municipal       1.00      1.00      1.00         1
#                         gobierno nacional estructura y funciones       1.00      1.00      1.00         1
#                                              gobierno provincial       1.00      1.00      1.00         1
#                                                gobierno regional       1.00      1.00      1.00         1
#                                             jefatura de gobierno       1.00      1.00      1.00         1
#                         juicio político acusación constitucional       1.00      1.00      1.00         1
#                                          justicia constitucional       1.00      1.00      1.00         1
#                                               justicia electoral       1.00      1.00      1.00         1
#                           ministerio público  defensoría pública       1.00      1.00      1.00         1
#                               plebiscitos referendos y consultas       1.00      1.00      1.00         1
#                            poder judicial estructura y funciones       1.00      1.00      1.00         1
#                                      presidencia de la república       1.00      1.00      1.00         1
# régimen de gobierno presidencial semipresidencial  parlamentario       1.00      1.00      1.00         1
#
#                                                      avg / total       1.00      1.00      1.00        21
# /Users/jperez/anaconda3/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
